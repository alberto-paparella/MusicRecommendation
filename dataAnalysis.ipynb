# %%
import pandas as pd
import numpy as np

# %%
TRAIN_DIM = 300
TEST_DIM = 100

# %%
data = pd.read_csv('src/main/resources/train_triplets.txt', sep="\t", header=None)
data.columns = ["user", "song", "play_count"]

# %%
data.head()
# Out:
#                                        user                song  play_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAPDEY12A81C210A9           1
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFNSP12AF72A0E22           1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFOVM12A58A7D494           1

# %%
print("Users: ", data['user'].unique().size, "\tSongs: ", data['song'].unique().size, "\tTriplets: ", data.shape[0])
# Out:
# Users:  1019318 	Songs:  384546 	Triplets:  48373586

# %%
users = data['user'].unique()

# %%
train = data[data['user'].isin(users[:TRAIN_DIM])]

# %%
train
# Out:
#                                            user                song  \
# 0      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAPDEY12A81C210A9
# 2      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 3      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFNSP12AF72A0E22
# 4      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFOVM12A58A7D494
# ...                                         ...                 ...
# 15322  14903f6491e335f4c5f9c42573d700e7ade59c5e  SOOXVDP12A8C13A769
# 15323  14903f6491e335f4c5f9c42573d700e7ade59c5e  SOPGRSL12A8C13D300
# 15324  14903f6491e335f4c5f9c42573d700e7ade59c5e  SOQXKUV12A6D4FB4C9
# 15325  14903f6491e335f4c5f9c42573d700e7ade59c5e  SOUTAKT12A8C13D31B
# 15326  14903f6491e335f4c5f9c42573d700e7ade59c5e  SOYLOZE12A8C13D313
#
#        play_count
# 0               1
# 1               1
# 2               2
# 3               1
# 4               1
# ...           ...
# 15322           1
# 15323           2
# 15324           1
# 15325           2
# 15326           1
#
# [15327 rows x 3 columns]

# %%
# Extracting test_full and using it instead of whole data in the cells below saves a lot of time
test_full = data[data['user'].isin(users[TRAIN_DIM:TRAIN_DIM+TEST_DIM])]

# %%
test_full
# Out:
#                                            user                song  \
# 15327  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADJQJ12A8C141D38
# 15328  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADOVQ12AB01797EB
# 15329  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADQPP12A67020C82
# 15330  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOAHLGV12AF72A6DFC
# 15331  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOAUDET12A6D4F96B7
# ...                                         ...                 ...
# 20493  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXILLO12A6310F1B6
# 20494  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXJLLK12A8C139E3D
# 20495  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXPFLM12A8AE48C50
# 20496  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXZUAV12A6310F21A
# 20497  788b4a6742e3591ee18533ff2193f7b3351e991e  SOYWBPL12B0B80BD74
#
#        play_count
# 15327           1
# 15328           1
# 15329           1
# 15330           1
# 15331           6
# ...           ...
# 20493           2
# 20494           1
# 20495           1
# 20496           1
# 20497           1
#
# [5171 rows x 3 columns]

# %%
for user in users[TRAIN_DIM:TRAIN_DIM+TEST_DIM]:
    print(test_full[test_full['user'] == user].shape[0], int(np.ceil(test_full[test_full['user'] == user].shape[0]/2)))
# Out:
# 206 103
# 14 7
# 44 22
# 43 22
# 29 15
# 36 18
# 54 27
# 21 11
# 41 21
# 129 65
# 23 12
# 13 7
# 15 8
# 12 6
# 50 25
# 10 5
# 26 13
# 30 15
# 22 11
# 219 110
# 10 5
# 23 12
# 16 8
# 22 11
# 18 9
# 19 10
# 12 6
# 54 27
# 10 5
# 52 26
# 13 7
# 84 42
# 60 30
# 20 10
# 14 7
# 120 60
# 20 10
# 17 9
# 33 17
# 71 36
# 118 59
# 43 22
# 31 16
# 36 18
# 21 11
# 18 9
# 194 97
# 115 58
# 104 52
# 108 54
# 25 13
# 16 8
# 15 8
# 35 18
# 39 20
# 278 139
# 35 18
# 49 25
# 35 18
# 110 55
# 16 8
# 60 30
# 20 10
# 15 8
# 14 7
# 29 15
# 21 11
# 10 5
# 12 6
# 12 6
# 114 57
# 43 22
# 12 6
# 46 23
# 10 5
# 16 8
# 43 22
# 19 10
# 27 14
# 226 113
# 10 5
# 17 9
# 17 9
# 19 10
# 41 21
# 208 104
# 35 18
# 69 35
# 46 23
# 17 9
# 62 31
# 24 12
# 36 18
# 67 34
# 253 127
# 31 16
# 19 10
# 153 77
# 88 44
# 44 22

# %%
test = pd.DataFrame(columns=data.columns)
test_labels = pd.DataFrame(columns=data.columns)
for user in users[TRAIN_DIM:TRAIN_DIM+TEST_DIM]:
   test = pd.concat([test,test_full[test_full['user'] == user][:int(np.ceil(test_full[test_full['user'] == user].shape[0]/2))]], axis=0)
   test_labels = pd.concat([test_labels,test_full[test_full['user'] == user][int(np.ceil(test_full[test_full['user'] == user].shape[0]/2)):]], axis=0)

# %%
test
# Out:
#                                            user                song play_count
# 15327  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADJQJ12A8C141D38          1
# 15328  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADOVQ12AB01797EB          1
# 15329  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOADQPP12A67020C82          1
# 15330  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOAHLGV12AF72A6DFC          1
# 15331  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOAUDET12A6D4F96B7          6
# ...                                         ...                 ...        ...
# 20471  788b4a6742e3591ee18533ff2193f7b3351e991e  SOIMCDE12A6D4F8383          1
# 20472  788b4a6742e3591ee18533ff2193f7b3351e991e  SOJFARO12AF72A709A          1
# 20473  788b4a6742e3591ee18533ff2193f7b3351e991e  SOKLHVK12A8C13404F          2
# 20474  788b4a6742e3591ee18533ff2193f7b3351e991e  SOKNWRZ12A8C13BF62          2
# 20475  788b4a6742e3591ee18533ff2193f7b3351e991e  SOKPWKZ12AB0182223          1
#
# [2608 rows x 3 columns]

# %%
test_labels
# Out:
#                                            user                song play_count
# 15430  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOMAIEW12A6D4F591E          3
# 15431  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOMBKJF12A8C1440B9          1
# 15432  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOMHEVM12A58A80951          3
# 15433  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOMSUCG12A8C13625B          1
# 15434  fe76c9d535c5834e4a9b91c13e29be6460cb79c4  SOMXQGH12A8C13CBEF          2
# ...                                         ...                 ...        ...
# 20493  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXILLO12A6310F1B6          2
# 20494  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXJLLK12A8C139E3D          1
# 20495  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXPFLM12A8AE48C50          1
# 20496  788b4a6742e3591ee18533ff2193f7b3351e991e  SOXZUAV12A6310F21A          1
# 20497  788b4a6742e3591ee18533ff2193f7b3351e991e  SOYWBPL12B0B80BD74          1
#
# [2563 rows x 3 columns]

# %%
for user in users[TRAIN_DIM:TRAIN_DIM+TEST_DIM]:
    print(test_full[test_full['user'] == user].shape[0], test[test['user'] == user].shape[0], test_labels[test_labels['user'] == user].shape[0])
# Out:
# 206 103 103
# 14 7 7
# 44 22 22
# 43 22 21
# 29 15 14
# 36 18 18
# 54 27 27
# 21 11 10
# 41 21 20
# 129 65 64
# 23 12 11
# 13 7 6
# 15 8 7
# 12 6 6
# 50 25 25
# 10 5 5
# 26 13 13
# 30 15 15
# 22 11 11
# 219 110 109
# 10 5 5
# 23 12 11
# 16 8 8
# 22 11 11
# 18 9 9
# 19 10 9
# 12 6 6
# 54 27 27
# 10 5 5
# 52 26 26
# 13 7 6
# 84 42 42
# 60 30 30
# 20 10 10
# 14 7 7
# 120 60 60
# 20 10 10
# 17 9 8
# 33 17 16
# 71 36 35
# 118 59 59
# 43 22 21
# 31 16 15
# 36 18 18
# 21 11 10
# 18 9 9
# 194 97 97
# 115 58 57
# 104 52 52
# 108 54 54
# 25 13 12
# 16 8 8
# 15 8 7
# 35 18 17
# 39 20 19
# 278 139 139
# 35 18 17
# 49 25 24
# 35 18 17
# 110 55 55
# 16 8 8
# 60 30 30
# 20 10 10
# 15 8 7
# 14 7 7
# 29 15 14
# 21 11 10
# 10 5 5
# 12 6 6
# 12 6 6
# 114 57 57
# 43 22 21
# 12 6 6
# 46 23 23
# 10 5 5
# 16 8 8
# 43 22 21
# 19 10 9
# 27 14 13
# 226 113 113
# 10 5 5
# 17 9 8
# 17 9 8
# 19 10 9
# 41 21 20
# 208 104 104
# 35 18 17
# 69 35 34
# 46 23 23
# 17 9 8
# 62 31 31
# 24 12 12
# 36 18 18
# 67 34 33
# 253 127 126
# 31 16 15
# 19 10 9
# 153 77 76
# 88 44 44
# 44 22 22

# %%
train.to_csv(r'src/main/resources/train_'+str(TRAIN_DIM)+'_'+str(TEST_DIM)+'.txt', header=None, index=None, sep='\t', mode='w')
test.to_csv(r'src/main/resources/test_'+str(TRAIN_DIM)+'_'+str(TEST_DIM)+'.txt', header=None, index=None, sep='\t', mode='w')
test_labels.to_csv(r'src/main/resources/test_labels_'+str(TRAIN_DIM)+'_'+str(TEST_DIM)+'.txt', header=None, index=None, sep='\t', mode='w')
